# %%
import pandas as pd

# %%
df_train=pd.read_csv('/Users/vishnubharathreddyvankireddy/Downloads/Table6.9.txt',sep='\t')

# %%
df_test=pd.read_csv('/Users/vishnubharathreddyvankireddy/Downloads/Table6.2.txt',sep='\t')

# %%
df_test
# Out:
#    House ID  Local Price  Bathrooms  Land Area  Living area  # Garages  \
# 0        24       6.0931        1.5     6.7265        1.652        1.0
# 1        25       8.3607        1.5     9.1500        1.777        2.0
# 2        26       8.1400        1.0     8.0000        1.504        2.0
# 3        27       9.1416        1.5     7.3262        1.831        1.5
# 4        28      12.0000        1.5     5.0000        1.200        2.0
#
#    # Rooms  # Bedrooms  Age of home Construction type
# 0        6           3           44         Apartment
# 1        8           4           48             House
# 2        7           3            3             House
# 3        8           4           31         Apartment
# 4        6           3           30         Apartment

# %%
k=df_train.iloc[:,:9]

# %%
df_train
# Out:
#     House ID  Local Price  Bathrooms  Land Area  Living area  # Garages  \
# 0          1       4.9176        1.0     3.4720        0.998        1.0
# 1          2       5.0208        1.0     3.5310        1.500        2.0
# 2          3       4.5429        1.0     2.2750        1.175        1.0
# 3          4       4.5573        1.0     4.0500        1.232        1.0
# 4          5       5.0597        1.0     4.4550        1.121        1.0
# 5          6       3.8910        1.0     4.4550        0.988        1.0
# 6          7       5.8980        1.0     5.8500        1.240        1.0
# 7          8       5.6039        1.0     9.5200        1.501        0.0
# 8          9      16.4202        2.5     9.8000        3.420        2.0
# 9         10      14.4598        2.5    12.8000        3.000        2.0
# 10        11       5.8282        1.0     6.4350        1.225        2.0
# 11        12       5.3003        1.0     4.9883        1.552        1.0
# ...

# %%
k
# Out:
#     House ID  Local Price  Bathrooms  Land Area  Living area  # Garages  \
# 0          1       4.9176        1.0     3.4720        0.998        1.0
# 1          2       5.0208        1.0     3.5310        1.500        2.0
# 2          3       4.5429        1.0     2.2750        1.175        1.0
# 3          4       4.5573        1.0     4.0500        1.232        1.0
# 4          5       5.0597        1.0     4.4550        1.121        1.0
# 5          6       3.8910        1.0     4.4550        0.988        1.0
# 6          7       5.8980        1.0     5.8500        1.240        1.0
# 7          8       5.6039        1.0     9.5200        1.501        0.0
# 8          9      16.4202        2.5     9.8000        3.420        2.0
# 9         10      14.4598        2.5    12.8000        3.000        2.0
# 10        11       5.8282        1.0     6.4350        1.225        2.0
# 11        12       5.3003        1.0     4.9883        1.552        1.0
# ...

# %%
final=df_test.iloc[:,:9]

# %%
final
# Out:
#    House ID  Local Price  Bathrooms  Land Area  Living area  # Garages  \
# 0        24       6.0931        1.5     6.7265        1.652        1.0
# 1        25       8.3607        1.5     9.1500        1.777        2.0
# 2        26       8.1400        1.0     8.0000        1.504        2.0
# 3        27       9.1416        1.5     7.3262        1.831        1.5
# 4        28      12.0000        1.5     5.0000        1.200        2.0
#
#    # Rooms  # Bedrooms  Age of home
# 0        6           3           44
# 1        8           4           48
# 2        7           3            3
# 3        8           4           31
# 4        6           3           30

# %%
df_train['Construction type']
# Out:
# 0     Apartment
# 1         House
# 2         Condo
# 3     Apartment
# 4     Apartment
# 5         Condo
# 6         Condo
# 7         House
# 8         Condo
# 9     Apartment
# 10        House
# 11        House
# 12        House
# 13        Condo
# 14    Apartment
# 15        House
# 16    Apartment
# 17        House
# 18        Condo
# 19    Apartment
# Name: Construction type, dtype: object

# %%
import numpy as np
from sklearn.datasets import fetch_20newsgroups
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, classification_report
 
import pandas as pd

import seaborn as sns
from matplotlib import pyplot as plt

# %matplotlib inline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.utils.multiclass import unique_labels

# %%
nb_model = MultinomialNB(alpha=1.0).fit(k,df_train['Construction type'])
y_hat_nb_test = nb_model.predict(final)
y_hat_nb_test
# Out:
# array(['House', 'House', 'House', 'House', 'House'], dtype='<U9')

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(k,df_train['Construction type'])

x_test1=count_vect.transform(final)

X_train_counts.shape
x_test1.shape
# Out:
# (9, 14)

# %%
df_train['Construction type'].unique()
# Out:
# array(['Apartment', 'House', 'Condo'], dtype=object)

# %%
categories=['Apartment', 'House', 'Condo']

# %%
type(k)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.metrics import confusion_matrix
mat=confusion_matrix(df_test['Construction type'],y_hat_nb_test)
sns.heatmap(mat.T,square=True,annot=True,fmt='d',cbar=False,xticklabels=unique_labels(df_test['Construction type']),yticklabels=unique_labels(df_test['Construction type']))
plt.xlabel('true')
plt.ylabel('predicted')
# Out:
# Text(91.68, 0.5, 'predicted')
